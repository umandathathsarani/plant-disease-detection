# %% [markdown]
# # Notebook 00: Exploratory Data Analysis (EDA)
#
# In this notebook, we will load the PlantDisease dataset and visualize samples to understand the variety of leaf diseases we are dealing with.

# %%
import os
import torch
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define the path to your dataset (Ensure this matches your folder name)
data_dir = '../data/raw/PlantVillage'

# Check if the path exists
if os.path.exists(data_dir):
    print(f"Dataset path confirmed: {data_dir}")
else:
    print(f"Please ensure the dataset is extracted at: {data_dir}")
# Out:
# Using device: cpu
# Dataset path confirmed: ../data/raw/PlantVillage
